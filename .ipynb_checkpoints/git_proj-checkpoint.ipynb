# %% [markdown]
# # Load and clean Australia data related job dataset

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import itertools
from matplotlib import pyplot as plt

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords 
import numpy as np
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/nanxu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/nanxu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/nanxu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
data_jobs_AU  = pd.read_csv('job_ad_unique_au_14122021.csv')

# %%
data_jobs_AU.head()
# Out:
#    Unnamed: 0                              job_title  \
# 0           0    Order Processing & Customer Service
# 1           1  Technical Business Analyst - Graduate
# 2           2              Data Analyst / Consultant
# 3           3               Data Entry Administrator
# 4           4                     Data Entry, Casual
#
#                                             job_link            company_name  \
# 0  /job/55244809?type=promoted#searchRequestToken...                KG Foods
# 1  /job/55325517?type=promoted#searchRequestToken...            DGIT Systems
# 2  /job/55305680?type=standard#searchRequestToken...       Cowra High School
# 3  /job/55321894?type=standout#searchRequestToken...  Link Resources Pty Ltd
# 4  /job/55320305?type=standard#searchRequestToken...     Insane Technologies
#
#                salary                   job_location  \
# 0                 NaN                         Sydney
# 1                 NaN                      Melbourne
# 2                 NaN  Blue Mountains & Central West
# 3                 NaN                 Sunshine Coast
# 4  $27 - $30 per hour                     Gold Coast
#
#                                     job_requirements  \
# 0  ['Attractive Remuneration Package', 'Based on ...
# 1  ['Technical Analyst role with exciting work', ...
# 2                                                NaN
# 3  ['Dynamic growing business providing opportuni...
# 4                                                NaN
#
#                         job_classifiation  \
# 0         Administration & Office Support
# 1  Information & Communication Technology
# 2                    Education & Training
# 3         Administration & Office Support
# 4         Administration & Office Support
#
#                                    short_description salary_ind  date_posted  \
# 0  Do you have an analytical mind, good attention...    0-60000          NaN
# 1  We’re looking for someone with practical devel...    0-60000          NaN
# 2         Data Analyst / Consultant for High Schools    0-60000          NaN
# 3  Data Entry Administrator Based on the Sunshine...    0-60000          NaN
# 4  Flexible work 20-40 hours per week, $27-$30 pe...    0-60000          NaN
#
#                            work_type  \
# 0                          Full time
# 1                          Full time
# 2                          Part time
# 3                          Full time
# 4  $27 - $30 per hourCasual/Vacation
#
#                                     long_description
# 0  Order Processing/Customer Service   Kids Gourm...
# 1  About DGITDGIT is a specialist telecommunicati...
# 2  EOI Expressions of Interest School Data Analys...
# 3  Link Resources Training is a Registered Traini...
# 4  We are based on the Gold Coast and protect sma...

# %% [markdown]
# Remove 2 columns 'Unnamed: 0' and 'date_posted'

# %%
AU_jobs = data_jobs_AU.drop(['Unnamed: 0','job_link','date_posted'], axis=1)

# %%
AU_jobs.columns.values
# Out:
# array(['job_title', 'company_name', 'salary', 'job_location',
#        'job_requirements', 'job_classifiation', 'short_description',
#        'salary_ind', 'work_type', 'long_description'], dtype=object)

# %%
AU_jobs.isnull().sum()
# Out:
# job_title               0
# company_name           33
# salary               1346
# job_location            0
# job_requirements      959
# job_classifiation       0
# short_description       0
# salary_ind              0
# work_type               1
# long_description        1
# dtype: int64

# %%
job_title = AU_jobs['job_title'].value_counts()
job_title
# Out:
# Business Analyst                                                104
# Data Analyst                                                     72
# Data Engineer                                                    45
# Senior Data Engineer                                             25
# Technical Business Analyst                                       25
#                                                                ...
# Data Analyst - 3 Month Contract                                   1
# Senior Process Business Analyst                                   1
# Senior Business Analyst - Remediation & Automation (Banking)      1
# Data/System Analyst Modellers                                     1
# Data & Business Analyst                                           1
# Name: job_title, Length: 1410, dtype: int64

# %%
AU_jobs['salary_ind'].value_counts()
# Out:
# 0-60000          514
# 60000-80000      364
# 200000-999999    311
# 150000-200000    275
# 120000-150000    210
# 80000-100000     207
# 100000-120000    177
# Name: salary_ind, dtype: int64

# %%
AU_jobs['work_type'].value_counts()
# Out:
# Full time                                                     890
# Contract/Temp                                                 388
# Casual/Vacation                                                37
# Part time                                                      30
# Base + Super + Profit ShareFull time                            9
#                                                              ...
# Base + Super + Performance Bonus + Share Options!Full time      1
# $120k to $170k base + superFull time                            1
# $850 - $900 p.d.Contract/Temp                                   1
# Competitive RemunerationFull time                               1
# Base Salary - Full Time - 6 Month ContractContract/Temp         1
# Name: work_type, Length: 610, dtype: int64

# %%
df = pd.DataFrame((AU_jobs['salary_ind']).str.replace('-',' ').str.split())
AU_jobs['Min_income'] = df.salary_ind.apply(lambda x: int(x[0]))
AU_jobs['Max_income'] = df.salary_ind.apply(lambda x: int(x[1]))
AU_jobs['avg_income'] = df.salary_ind.apply(lambda x: int(x[0]) if int(x[1])==999999 else int(x[1]) \
                                                      if int(x[0])==0 else (int(x[0])+int(x[1]))/2)

# %%
AU_jobs['avg_income'].value_counts()
# Out:
# 60000.0     514
# 70000.0     364
# 200000.0    311
# 175000.0    275
# 135000.0    210
# 90000.0     207
# 110000.0    177
# Name: avg_income, dtype: int64

# %%
AU_jobs.head()
# Out:
#                                job_title            company_name  \
# 0    Order Processing & Customer Service                KG Foods
# 1  Technical Business Analyst - Graduate            DGIT Systems
# 2              Data Analyst / Consultant       Cowra High School
# 3               Data Entry Administrator  Link Resources Pty Ltd
# 4                     Data Entry, Casual     Insane Technologies
#
#                salary                   job_location  \
# 0                 NaN                         Sydney
# 1                 NaN                      Melbourne
# 2                 NaN  Blue Mountains & Central West
# 3                 NaN                 Sunshine Coast
# 4  $27 - $30 per hour                     Gold Coast
#
#                                     job_requirements  \
# 0  ['Attractive Remuneration Package', 'Based on ...
# 1  ['Technical Analyst role with exciting work', ...
# 2                                                NaN
# 3  ['Dynamic growing business providing opportuni...
# 4                                                NaN
#
#                         job_classifiation  \
# 0         Administration & Office Support
# 1  Information & Communication Technology
# 2                    Education & Training
# 3         Administration & Office Support
# 4         Administration & Office Support
#
#                                    short_description salary_ind  \
# 0  Do you have an analytical mind, good attention...    0-60000
# 1  We’re looking for someone with practical devel...    0-60000
# 2         Data Analyst / Consultant for High Schools    0-60000
# 3  Data Entry Administrator Based on the Sunshine...    0-60000
# 4  Flexible work 20-40 hours per week, $27-$30 pe...    0-60000
#
#                            work_type  \
# 0                          Full time
# 1                          Full time
# 2                          Part time
# 3                          Full time
# 4  $27 - $30 per hourCasual/Vacation
#
#                                     long_description  Min_income  Max_income  \
# 0  Order Processing/Customer Service   Kids Gourm...           0       60000
# 1  About DGITDGIT is a specialist telecommunicati...           0       60000
# 2  EOI Expressions of Interest School Data Analys...           0       60000
# 3  Link Resources Training is a Registered Traini...           0       60000
# 4  We are based on the Gold Coast and protect sma...           0       60000
#
#    avg_income
# 0     60000.0
# 1     60000.0
# 2     60000.0
# 3     60000.0
# 4     60000.0

# %%
group_location = pd.DataFrame((AU_jobs.groupby(['job_location']))['avg_income'].mean())
group_location.sort_values(by =['avg_income'], ascending =False)
# Out:
#                                          avg_income
# job_location
# Kalgoorlie, Goldfields & Esperance    200000.000000
# ACT                                   137038.216561
# Sydney                                119832.439678
# Toowoomba & Darling Downs             117500.000000
# Brisbane                              116265.306122
# Melbourne                             109956.521739
# Darwin                                100454.545455
# Perth                                  98149.606299
# Northern QLD                           95000.000000
# Newcastle, Maitland & Hunter           94117.647059
# Adelaide                               93880.597015
# Ballarat & Central Highlands           90000.000000
# Port Macquarie & Mid North Coast       90000.000000
# Sunshine Coast                         89545.454545
# South West Coast VIC                   88636.363636
# Blue Mountains & Central West          85000.000000
# Shepparton & Goulburn Valley           83333.333333
# Wagga Wagga & Riverina                 80000.000000
# Dubbo & Central NSW                    78000.000000
# Albury Area                            77500.000000
# Gold Coast                             76666.666667
# Mackay & Coalfields                    75000.000000
# Bendigo, Goldfields & Macedon Ranges   75000.000000
# Coffs Harbour & North Coast            75000.000000
# Tamworth & North West NSW              73333.333333
# Wollongong, Illawarra & South Coast    72000.000000
# Gosford & Central Coast                70000.000000
# Gladstone & Central QLD                70000.000000
# Cairns & Far North                     70000.000000
# Mornington Peninsula & Bass Coast      65000.000000
# Port Hedland, Karratha & Pilbara       65000.000000
# Hobart                                 65000.000000
# Northam & Wheatbelt                    60000.000000
# Lismore & Far North Coast              60000.000000
# Hervey Bay & Fraser Coast              60000.000000
# Geraldton, Gascoyne & Midwest          60000.000000
# Southern Highlands & Tablelands        60000.000000
# Bundaberg & Wide Bay Burnett           60000.000000
# Bunbury & South West                   60000.000000
# Bairnsdale & Gippsland                 60000.000000
# Alice Springs & Central Australia      60000.000000

# %%
states = {'NSW':'New South Wales','QLD':'Queensland','SA':'South Australia','TAS':'Tasmania',\
          'AU_VIC':'Victoria','AU_WA':'Western Australia'}

# %%
AU_jobs['state'] = AU_jobs.job_location.apply(lambda x: 'Western Australia' if x == 'Kalgoorlie, Goldfields & Esperance' or x == 'Geraldton, Gascoyne & Midwest'\
                                                        else 'New South Wales' if ('NSW') in x or x =='ACT' or x =='Sydney' or x == 'Newcastle, Maitland & Hunter'\
                                                              or x == 'Port Macquarie & Mid North Coast' or x == 'Blue Mountains & Central West'\
                                                              or x == 'Coffs Harbour & North Coast' or x == 'Wollongong, Illawarra & South Coast' \
                                                              or x == 'Gosford & Central Coast' or x == 'Hobart' or x =='Lismore & Far North Coast'\
                                                              or x == 'Southern Highlands & Tablelands' or x == 'Wagga Wagga & Riverina' \
                                                              or x == 'Albury Area'   \
                                                        else 'Queensland' if x == 'Toowoomba & Darling Downs' or x =='Brisbane'\
                                                              or x == 'Hervey Bay & Fraser Coast'\
                                                        else 'Victoria' if ('VIC') in x or x == 'Melbourne' or x =='Ballarat & Central Highlands'\
                                                              or x =='Shepparton & Goulburn Valley' or x == 'Mornington Peninsula & Bass Coast' \
                                                              or x =='Bairnsdale & Gippsland' or x == 'Bendigo, Goldfields & Macedon Ranges'\
                                                        else 'Western Australia' if x == 'Perth' or x =='Port Hedland, Karratha & Pilbara'\
                                                              or x == 'Northam & Wheatbelt' or x == 'Bunbury & South West'\
                                                        else 'Queensland' if ('QLD') in x or x == 'Sunshine Coast' or x =='Mackay & Coalfields'\
                                                              or x =='Cairns & Far North' or x == 'Bundaberg & Wide Bay Burnett' or x == 'Gold Coast'\
                                                        else 'South Australia' if x == 'Adelaide'
                                                        else x)

# %%
avg_income_by_state = AU_jobs.groupby(['state'])['avg_income'].describe()[['count', 'mean']].sort_values(by='mean',ascending = False)
avg_income_by_state.reset_index(inplace = True)

# %%
# Figure Size
fig = plt.figure(figsize =(18, 7))
 
# Horizontal Bar Plot
plt.bar(avg_income_by_state['state'],avg_income_by_state['mean'])

# Set the font dictionaries (for plot title and axis titles)
title_font = {'fontname':'Arial', 'size':'20', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} 
axis_font = {'fontname':'Arial', 'size':'14'}

plt.title('Average income by state', **title_font)
plt.xlabel('State of Australia', **axis_font)
plt.ylabel('Average income $', **axis_font)

# Show Plot
plt.show()

# %%
nu_jobs_by_state = avg_income_by_state.sort_values(by='count',ascending = False)
# Figure Size
fig = plt.figure(figsize =(18, 7))
 
# Horizontal Bar Plot
plt.bar(nu_jobs_by_state['state'],nu_jobs_by_state['count'])

# Set the font dictionaries (for plot title and axis titles)
title_font = {'fontname':'Arial', 'size':'20', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} 
axis_font = {'fontname':'Arial', 'size':'14'}

plt.title('Number of job advertisements by state', **title_font)
plt.xlabel('State of Australia', **axis_font)
plt.ylabel('Average income $', **axis_font)

# Show Plot
plt.show()

# %% [markdown]
# Analyse job descriptions

# %% [markdown]
# Remove NaN in long_description column; One row with NaN long_description.

# %%
long_description = pd.DataFrame(AU_jobs['long_description'])
df = long_description[long_description['long_description'].notnull()]
df = df['long_description']

# %%
#This splits all the sentences up which makes it easier for us to work with

all_sentences = []

for word in df:
    all_sentences.append(word)

all_sentences
#df1 = df.to_string()

#df_split = df1.split()

#df_split

lines = list()
for line in all_sentences:    
    words = line.split()
    for w in words: 
       lines.append(w)
lines[0:100]
# Out:
# ['Order',
#  'Processing/Customer',
#  'Service',
#  'Kids',
#  'Gourmet',
#  'Food',
#  'is',
#  'a',
#  'volume',
#  'catering',
#  'business',
#  'and',
#  'the',
#  'National',
#  'leading',
#  'provider',
#  'of',
#  'prepared',
#  'meals',
#  'to',
#  'the',
#  'childcare',
#  'industry',
#  'in',
#  'Sydney,',
#  'Brisbane',
#  '&',
#  'Melbourne.',
#  'Our',
#  'growing',
#  'business',
#  'is',
#  'based',
#  'on',
#  'Sydney’s',
#  'Northern',
#  'Beaches,',
#  'and',
#  'we',
#  'are',
#  'looking',
#  'for',
#  'an',
#  'Order',
#  'Processing/Customer',
#  'Service',
#  'person.',
#  'Working',
#  'in',
#  'our',
#  'Business',
#  'Development',
#  'Team,',
#  'you',
#  'will',
#  'take',
#  'care',
#  'of',
#  'processing',
#  'orders',
#  'and',
#  'customer',
#  'service',
#  'related',
#  'activities.',
#  'We',
#  'are',
#  'looking',
#  'for',
#  'a',
#  'positive',
#  'and',
#  'energetic',
#  'team',
#  'member',
#  'with',
#  'database',
#  'experience',
#  'and',
#  'excellent',
#  'attention',
#  'to',
#  'detail.',
#  'This',
#  'is',
#  'a',
#  'full-time',
#  'position',
#  'with',
#  'office',
#  'hours',
#  '8am',
#  '–',
#  '4pm.',
#  'Key',
#  'Responsibilities',
#  'include:',
#  'Order',
#  'processing',
#  'and']

# %%
#Removing Punctuation

lines = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in lines]

lines2 = []

for word in lines:
    if word != '':
        lines2.append(word)
        
lines2[0:10]
# Out:
# ['Order',
#  'ProcessingCustomer',
#  'Service',
#  'Kids',
#  'Gourmet',
#  'Food',
#  'is',
#  'a',
#  'volume',
#  'catering']

# %% [markdown]
# Check what technical tool is mentioned in the long description

# %%
#Removing all Stop Words


stem2 = []
stopWords = set(stopwords.words('english'))
stopWords.update(['data','business','experience','work','team','role','Data','skills',
                 'working','We','The','including','across','You','within', 'ability',
                  'new','Business','Experience','please','This','apply','Australia','provide','services'])
for word in lines2:
    if word not in stopWords:
        stem2.append(word)

stem2[0:100]
# Out:
# ['Order',
#  'ProcessingCustomer',
#  'Service',
#  'Kids',
#  'Gourmet',
#  'Food',
#  'volume',
#  'catering',
#  'National',
#  'leading',
#  'provider',
#  'prepared',
#  'meals',
#  'childcare',
#  'industry',
#  'Sydney',
#  'Brisbane',
#  'Melbourne',
#  'Our',
#  'growing',
#  'based',
#  'Sydneys',
#  'Northern',
#  'Beaches',
#  'looking',
#  'Order',
#  'ProcessingCustomer',
#  'Service',
#  'person',
#  'Working',
#  'Development',
#  'Team',
#  'take',
#  'care',
#  'processing',
#  'orders',
#  'customer',
#  'service',
#  'related',
#  'activities',
#  'looking',
#  'positive',
#  'energetic',
#  'member',
#  'database',
#  'excellent',
#  'attention',
#  'detail',
#  'fulltime',
#  'position',
#  'office',
#  'hours',
#  '8am',
#  '4pm',
#  'Key',
#  'Responsibilities',
#  'include',
#  'Order',
#  'processing',
#  'printing',
#  'internal',
#  'website',
#  'Maintain',
#  'update',
#  'customer',
#  'database',
#  'Customer',
#  'service',
#  'support',
#  'Oversee',
#  'monitor',
#  'daily',
#  'transport',
#  'logistics',
#  'Developing',
#  'maintaining',
#  'effective',
#  'procedures',
#  'andor',
#  'processes',
#  'achieve',
#  'outputs',
#  'General',
#  'office',
#  'administration',
#  'typing',
#  'filing',
#  'entry',
#  'At',
#  'least',
#  '2',
#  'years',
#  'similar',
#  'suitable',
#  'Graduate',
#  'Confident',
#  'communicator',
#  'professional',
#  'friendly',
#  'telephone']

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
df = pd.DataFrame(stem2)
df = df[0].value_counts()
#df.to_csv('wordcount.csv')

# %%
#This will give frequencies of our words

from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 22803, 2: 5003, 3: 2216, 4: 1390, 5: 998, 6: 698, 7: 552, 8: 437, 9: 367, 10: 345, ...})

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#This is a simple plot that shows the top 20 words being used
#df.plot(20)

df = df[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df.values, df.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
# Text(0.5, 1.0, 'Top Words Overall')
# Text(0, 0.5, 'Word from Tweet')
# Text(0.5, 0, 'Count of Words')

# %%
AU_jobs['company_name'].value_counts()
# Out:
# Talent – SEEK Recruitment Agency of the Year | 7 Time Winner    30
# SEEK Limited                                                    26
# Bluefin Resources Pty Limited                                   25
# Recruitment Hive                                                19
# Paxus                                                           19
#                                                                 ..
# TasNetworks                                                      1
# Department of Treasury and Finance                               1
# AusHealth                                                        1
# Insane Technologies                                              1
# Fortescue Future Industries                                      1
# Name: company_name, Length: 1040, dtype: int64

# %%
def func(x):
    skills = ['python','r','django',"c++",'database','sql','sas','developer','cloud','visualisation','api']
    text = list(map(lambda y: y.lower(), x['long_description'].split()))
    for skill in skills:        
        if skill in text:
            x[skill+'_tag'] = 1
        else:
            x[skill+'_tag'] = 0
    return x

# %%
AU_jobs = AU_jobs[AU_jobs['long_description'].notnull()]
AU_jobs_complete = AU_jobs.apply(func,axis=1)
AU_jobs_complete.sample(10)
# Out:
#                                               job_title  \
# 501                                Data Science Manager
# 1628  Senior Manager, Market Data, Corporate Operati...
# 339                Project Manager - SaaS/Data Services
# 41                             Analyst - Technical Data
# 675                     Analytics and Reporting Officer
# 1157                         Data and Reporting Analyst
# 1608                   Senior Machine Learning Engineer
# 914                                        Data Analyst
# 1775                            Data Analyst | Power BI
# 266                                       Administrator
#
#                                            company_name  \
# 501   Talent – SEEK Recruitment Agency of the Year |...
# 1628                            Macquarie Group Limited
# 339   Talent – SEEK Recruitment Agency of the Year |...
# 41                                                  IAG
# 675                                            McArthur
# 1157  Endeavour Energy Network Operator Partnership ...
# 1608                          SustainAbility Consulting
# 914                                            TAFE NSW
# 1775                 First People Recruitment Solutions
# 266                                  flexhive by Hudson
#
#                                                 salary         job_location  \
# 501                                        Competitive            Melbourne
# 1628                                               NaN               Sydney
# 339                                                NaN            Melbourne
# 41    Competitive Salary, flexible working & 13% Super               Sydney
# 675                                                NaN             Adelaide
# 1157                                               NaN               Sydney
# 1608                    $145-$165k + Super + 10% Bonus               Sydney
# 914                                                NaN  Dubbo & Central NSW
# 1775                         APS6 hourly rate contract                  ACT
# 266                             $29 - $40 p.h. + Super             Brisbane
#
#                                        job_requirements  \
# 501   ['$$ Attractive Salary package // Bonuses', 'O...
# 1628  ['Join a high performing team', 'Dynamic envir...
# 339   ['11 month initial engagement', 'Strong WFH ca...
# 41                                                  NaN
# 675                                                 NaN
# 1157                                                NaN
# 1608                                                NaN
# 914                                                 NaN
# 1775  ["Aid in maximising the department's internati...
# 266   ['Flexible working arrangements - WFH or on-si...
#
#                            job_classifiation  \
# 501   Information & Communication Technology
# 1628    Manufacturing, Transport & Logistics
# 339   Information & Communication Technology
# 41                Insurance & Superannuation
# 675                     Government & Defence
# 1157  Information & Communication Technology
# 1608  Information & Communication Technology
# 914   Information & Communication Technology
# 1775                    Government & Defence
# 266          Administration & Office Support
#
#                                       short_description     salary_ind  \
# 501   Our client a tier 1 organisation located in Me...        0-60000
# 1628  Join the Macquarie Market Data team responsibl...  150000-200000
# 339   Exciting opportunity to be an integral part of...        0-60000
# 41    Your contribution is to assist in the enrichme...        0-60000
# 675   McArthur are currently seeking applications fr...    60000-80000
# 1157  Help provide data insights to assist with maki...  100000-120000
# 1608  Super exciting Senior Machine Learning Enginee...  150000-200000
# 914   •Full time temporary •Location negotiable acro...   80000-100000
# 1775  Utilise your data analysis techniques to assis...  200000-999999
# 266   Administration and office-based support roles ...        0-60000
#
#                                               work_type  \
# 501                                CompetitiveFull time
# 1628                                          Full time
# 339                                           Full time
# 41    Competitive Salary, flexible working & 13% Sup...
# 675                                       Contract/Temp
# 1157                                          Full time
# 1608            $145-$165k + Super + 10% BonusFull time
# 914                                       Contract/Temp
# 1775            APS6 hourly rate contract Contract/Temp
# 266                 $29 - $40 p.h. + SuperContract/Temp
#
#                                        long_description  ...  r_tag  \
# 501   Our client a tier 1 organisation located in Me...  ...      0
# 1628  Join the Macquarie Market Data team responsibl...  ...      0
# 339   Exciting opportunity to be an integral part of...  ...      0
# 41    Company description:READY FOR ANYTHINGAt IAG, ...  ...      0
# 675   **Must be an Australian Citizen able to gain b...  ...      0
# 1157  Company description:The Reporting & Insights b...  ...      0
# 1608  We're working with a high growth and forward t...  ...      0
# 914   \n\nFull time temporary  \nLocation negotiable...  ...      0
# 1775  About the RoleThis is a data analyst position....  ...      0
# 266   Administration and office-based support roles ...  ...      0
#
#       django_tag  c++_tag database_tag  sql_tag  sas_tag  developer_tag  \
# 501            0        0            0        0        0              0
# 1628           0        0            0        0        0              0
# 339            0        0            0        0        0              0
# 41             0        0            0        0        1              0
# 675            0        0            0        0        0              0
# 1157           0        0            0        1        0              0
# 1608           0        0            1        1        0              0
# 914            0        0            0        0        0              0
# 1775           0        0            0        1        0              0
# 266            0        0            0        0        0              0
#
#       cloud_tag  visualisation_tag  api_tag
# 501           1                  0        0
# 1628          0                  0        0
# 339           0                  0        0
# 41            0                  0        0
# 675           0                  0        0
# 1157          0                  1        0
# 1608          1                  0        0
# 914           0                  0        0
# 1775          0                  0        0
# 266           0                  0        0
#
# [10 rows x 25 columns]

# %%
Total = {
        'R': AU_jobs_complete['r_tag'].sum(), 
        'Django': AU_jobs_complete['django_tag'].sum(), 
        'C++': AU_jobs_complete['c++_tag'].sum(), 
        'Database': AU_jobs_complete['database_tag'].sum(), 
        'SQL': AU_jobs_complete['sql_tag'].sum(), 
        'SAS': AU_jobs_complete['sas_tag'].sum(), 
        'Developmer': AU_jobs_complete['developer_tag'].sum(), 
        'Cloud': AU_jobs_complete['cloud_tag'].sum(), 
        'Visualisation': AU_jobs_complete['visualisation_tag'].sum(), 
        'API': AU_jobs_complete['api_tag'].sum(),
        'Python': AU_jobs_complete['python_tag'].sum()
        }
Total
# Out:
# {'R': 74,
#  'Django': 0,
#  'C++': 7,
#  'Database': 268,
#  'SQL': 499,
#  'SAS': 50,
#  'Development': 85,
#  'Cloud': 284,
#  'Visualisation': 185,
#  'API': 35,
#  'Python': 173}
